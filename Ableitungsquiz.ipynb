# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider
import matplotlib as mpl
import matplotlib.patheffects
import backend
# %matplotlib widget

# %% [markdown]
# ## Ableitungsquiz

# %%
Quiz=backend.Ableitungquiz(10)
Quiz.questions(0)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Quiz.close_and_save_last_question(0)
Quiz.questions(1)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Quiz.close_and_save_last_question(1)
Quiz.questions(2)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Quiz.close_and_save_last_question(2)
Quiz.questions(3)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Quiz.close_and_save_last_question(3)
Quiz.questions(4)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Quiz.close_and_save_last_question(4)
Quiz.questions(5)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Quiz.close_and_save_last_question(5)
Quiz.questions(6)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Quiz.close_and_save_last_question(6)
Quiz.questions(7)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Quiz.close_and_save_last_question(7)
Quiz.questions(8)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Quiz.close_and_save_last_question(8)
Quiz.questions(9)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Du bist mit allen Fragen durch? Dann starte die Gesamtauswertung.

# %%
Quiz.close_and_save_last_question(9)
Quiz.evaluation()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Bei dieser Frage war die Abweichung: 0.3054070243104251
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Bei dieser Frage war die Abweichung: 0.13874035764375803
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Bei dieser Frage war die Abweichung: 0.2709063814866759
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Bei dieser Frage war die Abweichung: 0.5571090462833097
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Bei dieser Frage war die Abweichung: 0.2074421458625535
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Bei dieser Frage war die Abweichung: 0.22039007713885095
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Bei dieser Frage war die Abweichung: 0.2395429335501665
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Bei dieser Frage war die Abweichung: 0.5152875175315572
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Bei dieser Frage war die Abweichung: 0.43186798737727927
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Bei dieser Frage war die Abweichung: 0.037057328190743984
# _____________________________________________________________________
# Frage                  Abweichung
# 1                      0.3054070243104251
# 2                      0.13874035764375803
# 3                      0.2709063814866759
# 4                      0.5571090462833097
# 5                      0.2074421458625535
# 6                      0.22039007713885095
# 7                      0.2395429335501665
# 8                      0.5152875175315572
# 9                      0.43186798737727927
# 10                      0.037057328190743984
#                       __________
# Gesamtabweichung:      2.92375079937532

# %% [markdown]
# Vielen Dank für's Mitspielen. <br>
# Created with <3 by Simon Koppenhöfer
